# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/data_clean.csv")
df.head(1)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             Track       Album Album_type  \
# 0  Feel Good Inc.  Demon Days      album
#
#                                     Uri  Danceability  Energy  Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
#
# [1 rows x 28 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  20166.00000  20166.000000  20166.000000  20166.000000  20166.000000
# mean   10371.20118      0.620110      0.635034      5.300853     -7.659951
# std     5989.56573      0.165263      0.213788      3.577942      4.616296
# min        0.00000      0.000000      0.000020      0.000000    -46.251000
# 25%     5175.25000      0.519000      0.508000      2.000000     -8.824000
# 50%    10380.50000      0.638000      0.666000      5.000000     -6.535000
# 75%    15567.75000      0.741000      0.797000      8.000000     -4.938000
# max    20717.00000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20166.000000  20166.000000      20166.000000  20166.000000
# mean       0.096138      0.289069          0.055945      0.191380
# std        0.110334      0.286047          0.193130      0.165329
# ...

# %%
from sklearn.preprocessing import StandardScaler

columns = [
    # 'Danceability',
    'Energy',
    'Speechiness',
    # 'Acousticness',
    # 'Instrumentalness',
    # 'Valence',
    # 'Tempo'
]
scaler = StandardScaler()
cleaned_df = pd.DataFrame(scaler.fit_transform(df[columns]), columns=columns)
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19471 entries, 0 to 20165
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Energy       19471 non-null  float64
#  1   Speechiness  19471 non-null  float64
# dtypes: float64(2)
# memory usage: 456.4 KB

# %%
from sklearn.metrics.pairwise import cosine_similarity

index = 0
cos_sim = cosine_similarity(cleaned_df.iloc[[index]], cleaned_df)
best_index = np.argsort(cos_sim)[0][::-1][1:6]
best_index
# Out:
# array([  272, 14165, 14522,   415, 10652])

# %%
df.iloc[best_index].loc[:, columns]
# Out:
#        Energy  Speechiness
# 272     0.748       0.0323
# 14165   0.830       0.1060
# 14522   0.738       0.0292
# 415     0.820       0.2430
# 10652   0.807       0.0972

# %%
df.iloc[[index]].loc[:, columns]
# Out:
#    Energy  Speechiness
# 0   0.705        0.177
